# %%
# correlation
# price prediction 

# data combine 
# show correlation
# train linear regression on one year worth of data
# store linear regression model in flask
# predict estimated price based on that day's sentiment 
# display result

# %%
#  data combine 

# get panel data first and add a date column for processing
import pandas as pd
from pandas_datareader import data
tickers = ['AAPL']

start_date = '2020-04-29'
end_date = '2021-10-10'

# User pandas_reader.data.DataReader to load data
panel_data = data.DataReader(tickers,'yahoo', start_date, end_date)
panel_data["date"] = panel_data.index
panel_data["date"] = pd.to_datetime(panel_data['date'])

# get reddit data or whatever for analysis and convert date type
reddit_data = pd.read_csv("./Reddit/cleaned_AAPL_sentiment.csv")
reddit_data["date"] = pd.to_datetime(reddit_data['date'])

# add day names for each of the two df 
from datetime import date
import calendar
for index, row in reddit_data.iterrows():
    reddit_data.at[index,"day_name"] = calendar.day_name[row["date"].weekday()]
    
for index, row in panel_data.iterrows():
    date = pd.to_datetime(row["date"].values[0])
    panel_data.at[index,"day_name"]  = calendar.day_name[date.weekday()]

# %%
reddit_data

for index, row in reddit_data.iterrows():
    if row['flair_sentiment'] == "NEGATIVE":
        reddit_data.at[index,"flair_sentiment_score"] = 0 - row['flair_sentiment_score']
    if row['finbert_sentiment'] == "negative":
        reddit_data.at[index,"finbert_score"] = 0 - row['flair_sentiment_score']
    if row['finbert_sentiment'] == "neutral":
        reddit_data.at[index,"finbert_score"] = 0

# %%
# groupby dates for panel data and sentiment data  
# note that weekends are missing for panel data
panel_groupby = panel_data.groupby(["date"]).mean()

# %%
reddit_data
# Out:
#                                                     text       date  likes  \
# 0      Fiona Apple Returns to No. 1 on Top Rock Album... 2020-04-29      1
# 1      Dow Jones Futures: Tesla, Facebook, Microsoft,... 2020-04-29      1
# 2      Apple's flexible batteries patent hints at fol... 2020-04-29      1
# 3      Apple Q2 2020 earnings will be all about asses... 2020-04-29      1
# 4      Apple, Google release virus contact-tracing to... 2020-04-29      1
# ...                                                  ...        ...    ...
# 28687  I see your caveat on understanding the limitat... 2021-10-10      1
# 28688  So I hold VTI at 70% of my investments, QQQM f... 2021-10-10      1
# 28689  I'm kinda newbie too, maybe bit more experienc... 2021-10-10      1
# 28690  Not just the anti-trust but look up the percen... 2021-10-10      1
# 28691  I see your caveat on understanding the limitat... 2021-10-10      1
#
#        subreddit                                       cleaned_text  \
# 0         google   fiona returns top rock albums chart bolt cutters
# 1         google  dow jones futures facebook buy zones coronavir...
# 2         google  flexible batteries patent hints foldable iphon...
# 3         google                          earnings assessing damage
# 4         google                     release virus tools app makers
# ...          ...                                                ...
# 28687  investing  see caveat understanding limitations encourage...
# 28688  investing  hold vti investments qqqm schd blue chip stock...
# 28689  investing  kinda newbie maybe bit experienced long buy qu...
# 28690  investing  look percentage portfolio top heck even top co...
# 28691  investing  see caveat understanding limitations encourage...
#
#       flair_sentiment  flair_sentiment_score vader_sentiment  vader_score  \
# 0            POSITIVE                 0.9957             neu       0.2023
# 1            NEGATIVE                 0.6229             neu       0.0000
# 2            POSITIVE                 0.9897             neu       0.2263
# 3            POSITIVE                 0.6713             neg      -0.4939
# 4            POSITIVE                 0.7020             neu       0.0000
# ...               ...                    ...             ...          ...
# 28687        NEGATIVE                 0.9990             neu       0.8910
# 28688        NEGATIVE                 0.7064             neu      -0.0516
# 28689        POSITIVE                 0.7927             neu       0.7650
# 28690        NEGATIVE                 0.8874             neu       0.9865
# 28691        NEGATIVE                 0.9990             neu       0.8910
#
#       finbert_sentiment  finbert_score   day_name
# 0               neutral       0.766225  Wednesday
# 1              positive       0.482211  Wednesday
# 2               neutral       0.745737  Wednesday
# 3               neutral       0.901693  Wednesday
# 4               neutral       0.926601  Wednesday
# ...                 ...            ...        ...
# 28687           neutral       0.858922     Sunday
# 28688           neutral       0.613409     Sunday
# 28689           neutral       0.827923     Sunday
# 28690           neutral       0.559159     Sunday
# 28691           neutral       0.858922     Sunday
#
# [28692 rows x 12 columns]

# %%
reddit_groupby = reddit_data.groupby(["date"]).mean()
reddit_groupby
# Out:
#                likes  flair_sentiment_score  vader_score  finbert_score
# date
# 2020-01-05  1.000000               0.906725     0.041850       0.842132
# 2020-01-06  1.000000               0.950256    -0.000011       0.837403
# 2020-01-07  1.000000               0.871989     0.060814       0.816533
# 2020-01-08  1.000000               0.916327     0.053881       0.801635
# 2020-01-09  1.290000               0.919680     0.184554       0.824573
# ...              ...                    ...          ...            ...
# 2021-12-05  3.457364               0.938308     0.281212       0.834855
# 2021-12-06  2.973684               0.973097     0.579839       0.827114
# 2021-12-07  7.166667               0.836667     0.415522       0.869606
# 2021-12-08  2.833333               0.938022     0.237433       0.846114
# 2021-12-09  5.533333               0.918060     0.470167       0.821779
#
# [508 rows x 4 columns]

# %%
merge=pd.merge(reddit_groupby,panel_groupby, how='inner', left_index=True, right_index=True)
# Out:
# C:\Users\Shawn\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)

# %%
merge.corr()
# Out:
#                           likes  flair_sentiment_score  vader_score  \
# likes                  1.000000              -0.058197     0.256752
# flair_sentiment_score -0.058197               1.000000    -0.113955
# vader_score            0.256752              -0.113955     1.000000
# finbert_score         -0.155584               0.091057    -0.147547
# (Adj Close, AAPL)      0.334455               0.029267     0.526453
# (Close, AAPL)          0.332319               0.029365     0.526025
# (High, AAPL)           0.329207               0.032432     0.526877
# (Low, AAPL)            0.333587               0.032180     0.523649
# (Open, AAPL)           0.327397               0.032911     0.524990
# (Volume, AAPL)        -0.246790              -0.012170    -0.335684
#
#                        finbert_score  (Adj Close, AAPL)  (Close, AAPL)  \
# likes                      -0.155584           0.334455       0.332319
# flair_sentiment_score       0.091057           0.029267       0.029365
# vader_score                -0.147547           0.526453       0.526025
# finbert_score               1.000000          -0.206751      -0.206349
# (Adj Close, AAPL)          -0.206751           1.000000       0.999959
# (Close, AAPL)              -0.206349           0.999959       1.000000
# (High, AAPL)               -0.207491           0.997799       0.997916
# (Low, AAPL)                -0.201551           0.998205       0.998106
# (Open, AAPL)               -0.204714           0.995619       0.995634
# (Volume, AAPL)              0.001904          -0.458546      -0.455175
#
#                        (High, AAPL)  (Low, AAPL)  (Open, AAPL)  (Volume, AAPL)
# likes                      0.329207     0.333587      0.327397       -0.246790
# flair_sentiment_score      0.032432     0.032180      0.032911       -0.012170
# vader_score                0.526877     0.523649      0.524990       -0.335684
# finbert_score             -0.207491    -0.201551     -0.204714        0.001904
# (Adj Close, AAPL)          0.997799     0.998205      0.995619       -0.458546
# (Close, AAPL)              0.997916     0.998106      0.995634       -0.455175
# (High, AAPL)               1.000000     0.997697      0.998385       -0.432386
# (Low, AAPL)                0.997697     1.000000      0.997771       -0.473175
# (Open, AAPL)               0.998385     0.997771      1.000000       -0.444980
# (Volume, AAPL)            -0.432386    -0.473175     -0.444980        1.000000

# %%
# #  missing weekends - add weekend prices, leave it at friday 
# #  use the weighted sentiment 

# def weighted_weekends(data):
#     weighted_flair = weighted_vader = weighted_finbert = 0
#     new_df = []
#     for index, row in data.iterrows():
        
#         day = index.weekday()
#         if (day == 5): # saturday
#             weighted_flair += row['flair_sentiment_score'] * 0.2
#             weighted_vader += row['vader_score'] * 0.2
#             weighted_finbert += row['finbert_score'] * 0.2
#         elif (day == 6): # sunday
#             weighted_flair += row['flair_sentiment_score'] * 0.3
#             weighted_vader += row['vader_score'] * 0.3
#             weighted_finbert += row['finbert_score'] * 0.3
#         elif (day == 0): # monday
#             weighted_flair += row['flair_sentiment_score'] * 0.5
#             weighted_vader += row['vader_score'] * 0.5
#             weighted_finbert += row['finbert_score'] * 0.5
#             new_df.append([index, weighted_flair, weighted_vader, weighted_finbert])
#             weighted_flair = weighted_vader = weighted_finbert = 0
#         else:
#             new_df.append([index, row['flair_sentiment_score'], row['vader_score'], row['finbert_score']])
            
#     return new_df
