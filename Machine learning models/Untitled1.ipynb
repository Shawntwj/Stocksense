# %%
import pandas as pd

test = pd.read_csv("stocktwits_combined.csv")
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   person_id              1048575 non-null  int64
#  1   content                1048575 non-null  object
#  2   date_created           1048575 non-null  object
#  3   time_created           1048575 non-null  object
#  4   username               1048575 non-null  object
#  5   name                   1048518 non-null  object
#  6   join_date              1048575 non-null  object
#  7   official               1048575 non-null  bool
#  8   followers              1048575 non-null  int64
#  9   upload_source          1048575 non-null  object
#  10  likes                  1048575 non-null  int64
#  11  cleaned content        1048575 non-null  object
#  12  flair_sentiment        1048575 non-null  object
#  13  flair_sentiment_score  1048575 non-null  float64
# ...

# %%
test[len(test["content"].split()) > 5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-19e7efe287bd> in <module>
# ----> 1 test[len(test["content"].split()) > 5]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
test[test["followers"] > 50]
# Out:
#          person_id                                            content  \
# 1        389611544  $AAPL  @ $137.50    Will we buy her when she g...
# 3        389610405  $AMZN $GOOGL $TSLA $AAPL $SHOP buy when dips 💪💰✔️
# 4        389610042  SPACs Equity Research and Bowling. \n \nRead h...
# 5        389609655  $AAPL NEW ARTICLE : Apple's Dividend Growth an...
# 8        389608982  $AAPL see getting the Bulls excited. Let's e s...
# ...            ...                                                ...
# 1048559  283476175  $VXRT I like how certain board members mysteri...
# 1048561  283475968  $VXRT Pump and slump, another wall st. scam, s...
# 1048562  283475693  $VXRT this makes zero sense. \n\nAnyone using ...
# 1048568  283475007     $VXRT this shit is going to 5.00 dollars watch
# 1048571  283474083  $VXRT this is bogus, not even bouncing. Need t...
#
#         date_created time_created           username           name  \
# ...

# %%
len(test["content"].tolist())
# Out:
# 1048575

# %%
test["content"].tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2aa05bd9bbc2> in <module>
# ----> 1 test["content"].tolist().split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
n = 0
for i in test[test["followers"] > 50]["content"].tolist():
    if len(i.split()) > 5:
        n+=1 
print(n)
# Out:
# 395972
