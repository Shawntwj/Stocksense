# %%
import os 
print(os.getcwd())

import glob

all_csv = glob.glob("*.csv")
print(all_csv)
# Out:
# C:\Users\Shawn\PROJECT\Stocksense\Data\Twitter\cleaned
# ['AAPL_cleaned.csv', 'AAPL_cleaned_sentiment.csv', 'AMZN_cleaned.csv', 'AMZN_cleaned_sentiment.csv', 'ARKK_cleaned.csv', 'ARKK_cleaned_sentiment.csv', 'ATER_cleaned.csv', 'ATER_cleaned_sentiment.csv', 'GOOGL_cleaned.csv', 'GOOGL_cleaned_sentiment.csv', 'MSFT_cleaned.csv', 'MSFT_cleaned_sentiment.csv', 'Russell 1000_cleaned.csv', 'Russell 1000_cleaned_sentiment.csv', 'TSLA_cleaned.csv', 'TSLA_cleaned_sentiment.csv', 'VXRT_cleaned.csv', 'VXRT_cleaned_sentiment.csv']

# %% [markdown]
# # Flair

# %%
#!pip install flair

# %%
import pandas as pd
import flair
flair_sentiment = flair.models.TextClassifier.load('en-sentiment')  # Load model


def flair_senitment(ticketdf):
    for index, row in ticketdf.iterrows():
        s = flair.data.Sentence(row["cleaned Tweet"])  # Retrieve title of post
        flair_sentiment.predict(s) 
        sentiment = str(s.labels[0]).split()[0]
        score = str(s.labels[0]).split()[1][1:-1]

        ticketdf.at[index,'flair_sentiment'] = sentiment
        ticketdf.at[index,'flair_sentiment_score'] = score

    return ticketdf
# Out:
# 2021-10-19 00:00:26,070 loading file C:\Users\Shawn\.flair\models\sentiment-en-mix-distillbert_4.pt

# %% [markdown]
# # Vader

# %%
# import nltk
# nltk.download('vader_lexicon')

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

def vader_senitment(ticketdf):
    for index, row in ticketdf.iterrows():

        vs = sia.polarity_scores(row["cleaned Tweet"])

        score = vs["compound"]
        del vs['compound']
        sentiment = max(vs, key=vs.get)

        ticketdf.at[index,'vader_sentiment'] = sentiment
        ticketdf.at[index,'vader_score'] = score
    

    return ticketdf

# %% [markdown]
# # Finbert

# %%
# !pip install happytransformer

# %%
import pandas as pd
from happytransformer import HappyTextClassification 
happy_tc = HappyTextClassification("BERT", "ProsusAI/finbert", num_labels=3)


def finbert_senitment(ticketdf):

    for index, row in ticketdf.iterrows():
        result = happy_tc.classify_text(row["cleaned Tweet"])
        sentiment = result.label
        score = result.score

        ticketdf.at[index,'finbert_sentiment'] = sentiment
        ticketdf.at[index,'finbert_score'] = score
    
    return ticketdf
# Out:
# 10/19/2021 00:00:49 - INFO - happytransformer.happy_transformer -   Using model: cpu

# %%
for file in all_csv:
    file_df = pd.read_csv(file)
    file_df.head()
    print("======start======")
    file_df = flair_senitment(file_df) 
    print("flair done")
    print(file)
    file_df = vader_senitment(file_df)
    print("vader done")
    file_df = finbert_senitment(file_df)
    print("finbert done")
    filename = file.split(".")[0] + "_sentiment.csv"
    
    file_df.to_csv(filename,index=False)
    print(file,"done")
# Out:
# ======start======
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-52dcae1b20b4> in <module>
#       3     file_df.head()
#       4     print("======start======")
# ----> 5     file_df = flair_senitment(file_df)
#       6     print("flair done")
#       7     print(file)
#
# <ipython-input-24-5ccb0af62dd3> in flair_senitment(ticketdf)
#       7     for index, row in ticketdf.iterrows():
#       8         s = flair.data.Sentence(row["cleaned Tweet"])  # Retrieve title of post
# ----> 9         flair_sentiment.predict(s)
#      10         sentiment = str(s.labels[0]).split()[0]
#      11         score = str(s.labels[0]).split()[1][1:-1]
#
# ~\anaconda3\lib\site-packages\flair\nn\model.py in predict(self, sentences, mini_batch_size, return_probabilities_for_all_classes, verbose, label_name, return_loss, embedding_storage_mode)
#     513                     sentence.remove_labels(label_name)
#     514
# --> 515                 scores, gold_labels, sentences, label_candidates = self.forward_pass(batch,
#     516                                                                                      return_label_candidates=True)
#     517                 if return_loss:
#
# ~\anaconda3\lib\site-packages\flair\models\text_classification_model.py in forward_pass(self, sentences, return_label_candidates)
#      58
#      59         # embed sentences
# ---> 60         self.document_embeddings.embed(sentences)
#      61
#      62         # make tensor for all embedded sentences in batch
#
# ~\anaconda3\lib\site-packages\flair\embeddings\base.py in embed(self, sentences)
#      58
#      59         if not everything_embedded or not self.static_embeddings:
# ---> 60             self._add_embeddings_internal(sentences)
#      61
#      62         return sentences
#
# ~\anaconda3\lib\site-packages\flair\embeddings\document.py in _add_embeddings_internal(self, sentences)
#     152             # put encoded batch through transformer model to get all hidden states of all encoder layers
#     153             hidden_states = self.model(input_ids, attention_mask=mask)[-1] if len(sentences) > 1 \
# --> 154                 else self.model(input_ids)[-1]
#     155
#     156             # iterate over all subtokenized sentences
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     487         if inputs_embeds is None:
#     488             inputs_embeds = self.embeddings(input_ids)  # (bs, seq_length, dim)
# --> 489         return self.transformer(
#     490             x=inputs_embeds,
#     491             attn_mask=attention_mask,
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     312                 all_hidden_states = all_hidden_states + (hidden_state,)
#     313
# --> 314             layer_outputs = layer_module(
#     315                 x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     316             )
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     256         """
#     257         # Self-Attention
# --> 258         sa_output = self.attention(
#     259             query=x,
#     260             key=x,
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py in forward(self, query, key, value, mask, head_mask, output_attentions)
#     185             return x.transpose(1, 2).contiguous().view(bs, -1, self.n_heads * dim_per_head)
#     186
# --> 187         q = shape(self.q_lin(query))  # (bs, n_heads, q_length, dim_per_head)
#     188         k = shape(self.k_lin(key))  # (bs, n_heads, k_length, dim_per_head)
#     189         v = shape(self.v_lin(value))  # (bs, n_heads, k_length, dim_per_head)
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      94
#      95     def forward(self, input: Tensor) -> Tensor:
# ---> 96         return F.linear(input, self.weight, self.bias)
#      97
#      98     def extra_repr(self) -> str:
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1845     if has_torch_function_variadic(input, weight):
#    1846         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1847     return torch._C._nn.linear(input, weight, bias)
#    1848
#    1849
#
# KeyboardInterrupt:
