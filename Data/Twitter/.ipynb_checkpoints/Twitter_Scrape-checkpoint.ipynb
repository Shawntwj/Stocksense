# %% [markdown]
# https://betterprogramming.pub/how-to-scrape-tweets-with-snscrape-90124ed006af
#
# - stocks:
# VXRT, Russell 1000, ARKK, ATER,
# AAPL, TSLA, MFST, GOOGL, AMZN
#
# - What to scrape:
# Username,
# tweet,
# datetime,
# number of followers,
# num_comments / retweets,
# number of likes / score

# %%
# !python -m pip uninstall snscrape --yes
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# WARNING: Skipping snscrape as it is not installed.
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\shawn\appdata\local\temp\pip-req-build-ighgztdy
# Requirement already satisfied: requests[socks] in c:\users\shawn\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (2.25.1)
# Requirement already satisfied: lxml in c:\users\shawn\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (4.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\shawn\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (4.9.3)
# Requirement already satisfied: pytz in c:\users\shawn\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (2021.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shawn\anaconda3\lib\site-packages (from beautifulsoup4->snscrape==0.3.5.dev139+g35fb61a) (2.2.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\shawn\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shawn\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\shawn\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shawn\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (2020.12.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\shawn\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (1.7.1)
# Building wheels for collected packages: snscrape
#   Building wheel for snscrape (setup.py): started
#   Building wheel for snscrape (setup.py): finished with status 'done'
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev139+g35fb61a-py3-none-any.whl size=52218 sha256=5109c77af9f5167338d462416cce8a69e9581088a6d6fc9847125f300d670af4
#   Stored in directory: C:\Users\Shawn\AppData\Local\Temp\pip-ephem-wheel-cache-bfxtwm2v\wheels\92\42\87\33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.5.dev139+g35fb61a
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\Shawn\AppData\Local\Temp\pip-req-build-ighgztdy'

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
queries = ["VXRT", "Russell 1000", "ARKK", "ATER", "AAPL", "TSLA", "MFST", "GOOGL", "AMZN"]
queries = ["VXRT"]
for query in queries:
    # Creating list to append tweet data to
    tweets_list = []
    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query+' since:2021-01-01 until:2021-10-01').get_items()):
        # min word length = 5, min like = 200, min followers = 50, min retweet = 5
        if len(tweet.content.split())>=5 and tweet.likeCount>=200 and tweet.user.followersCount>=50 and tweet.retweetCount>=5:
            tweets_list.append([tweet.user.username, tweet.content, tweet.date, tweet.user.followersCount, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    tweets_df = pd.DataFrame(tweets_list)
    # Creating a dataframe from the tweets list above
#     tweets_df = pd.DataFrame(tweets_list, columns=['Username', 'Tweet', 'Datetime', 'Number of Followers', 'Number of Comments', 'Number of Retweets', 'Number of Likes'])
    tweets_df.head(10)
#     tweets_df.to_csv(query+".csv")

# %%
tweets_df
